# %% [markdown]
# <a href="https://colab.research.google.com/github/vitoriaferreirap/DeepLearning/blob/main/CNN_Computer_Vision/3_TrainNetwork_Predicao_VideoAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## First, go to "Runtime" ->"change runtime type"->select "Python3", and then select "GPU"
#
# As the COLAB environments were updated to CUDA 12.X and Python 3.11, we need to install DeepLabCut and TensorFlow in a distinct way to get TensorFlow to connect to the GPU.

# %%
# this will take a couple of minutes to install all the dependencies!
# !pip install --pre deeplabcut
# Out:
# Requirement already satisfied: deeplabcut in /usr/local/lib/python3.12/dist-packages (3.0.0rc13)
# Requirement already satisfied: albumentations<=1.4.3 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (1.4.3)
# Requirement already satisfied: dlclibrary>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.0.11)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.8.2)
# Requirement already satisfied: filterpy>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (1.4.5)
# Requirement already satisfied: ruamel.yaml>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.19.1)
# Requirement already satisfied: imgaug>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.4.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.6.0)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.60.0)
# Requirement already satisfied: matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (3.8.4)
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (3.6.1)
# Requirement already satisfied: numpy<2.0.0,>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (1.26.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (2.2.2)
# Requirement already satisfied: scikit-image>=0.17 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.25.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (1.6.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (1.16.3)
# Requirement already satisfied: statsmodels>=0.11 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.14.6)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (1.0.25)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (0.25.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (4.67.3)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (2.0.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (6.0.3)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (11.3.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.12/dist-packages (from deeplabcut) (3.10.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from albumentations<=1.4.3->deeplabcut) (4.15.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from albumentations<=1.4.3->deeplabcut) (4.11.0.86)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from dlclibrary>=0.0.7->deeplabcut) (1.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from imgaug>=0.4.0->deeplabcut) (1.17.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from imgaug>=0.4.0->deeplabcut) (4.11.0.86)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from imgaug>=0.4.0->deeplabcut) (2.37.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from imgaug>=0.4.0->deeplabcut) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.7.0,!=3.7.1,<3.9,>=3.3->deeplabcut) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->deeplabcut) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut) (2025.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.17->deeplabcut) (2026.2.24)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.17->deeplabcut) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->deeplabcut) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->deeplabcut) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.11->deeplabcut) (1.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (3.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->deeplabcut) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->deeplabcut) (1.4.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.12/dist-packages (from tables->deeplabcut) (2.14.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from tables->deeplabcut) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from tables->deeplabcut) (4.0.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->deeplabcut) (0.7.0)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.12/dist-packages (from blosc2>=2.3.0->tables->deeplabcut) (1.10.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from blosc2>=2.3.0->tables->deeplabcut) (1.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from blosc2>=2.3.0->tables->deeplabcut) (2.32.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->deeplabcut) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (0.24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->deeplabcut) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->blosc2>=2.3.0->tables->deeplabcut) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->blosc2>=2.3.0->tables->deeplabcut) (2.5.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub->dlclibrary>=0.0.7->deeplabcut) (0.1.2)

# %% [markdown]
# **(Be sure to click "RESTART RUNTIME" if it is displayed above before moving on !)** You will see this button at the output of the cells above ^.

# %%
import deeplabcut
# Out:
# Loading DLC 3.0.0rc13...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %% [markdown]
# ## Link your Google Drive (with your labeled data, or the demo data):
#
# ### First, place your project folder into you google drive! "i.e. move the folder named "Project-YourName-TheDate" into google drive.

# %%
# Now, let's link to your GoogleDrive. Run this cell and follow the authorization instructions:
# (We recommend putting a copy of the github repo in your google drive if you are using the demo "examples")

from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# YOU WILL NEED TO EDIT THE PROJECT PATH **in the config.yaml file** TO BE SET TO YOUR GOOGLE DRIVE LINK!
#
# Typically, this will be: `/content/drive/My Drive/yourProjectFolderName`

# %%
# PLEASE EDIT THIS:
project_folder_name = "deeplabcut/30FPS-cavaloTeste1-2026-03-03"
video_type = "mp4" #, mp4, MOV, or avi, whatever you uploaded!

# No need to edit this, we are going to assume you put videos you want to analyze
# in the "videos" folder, but if this is NOT true, edit below:
videofile_path = [f"/content/drive/My Drive/{project_folder_name}/videos/teste1_30fps.mp4"]
print(videofile_path)

# The prediction files and labeled videos will be saved in this `labeled-videos` folder
# in your project folder; if you want them elsewhere, you can edit this;
# if you want the output files in the same folder as the videos, set this to an empty string.
destfolder = f"/content/drive/MyDrive/{project_folder_name}/labeled-videos"

#No need to edit this, as you set it when you passed the ProjectFolderName (above):
path_config_file = f"/content/drive/MyDrive/{project_folder_name}/config.yaml"
print(path_config_file)

# This creates a path variable that links to your Google Drive project
# Out:
# ['/content/drive/My Drive/deeplabcut/30FPS-cavaloTeste1-2026-03-03/videos/teste1_30fps.mp4']
# /content/drive/MyDrive/deeplabcut/30FPS-cavaloTeste1-2026-03-03/config.yaml

# %% [markdown]
# ## Create a training dataset:
#
# ### You must do this step inside of Colab
#
# After running this script the training dataset is created and saved in the project directory under the subdirectory **'training-datasets'**
#
# This function also creates new subdirectories under **dlc-models-pytorch** and appends the project config.yaml file with the correct path to the training and testing pose configuration file. These files hold the parameters for training the network. Such an example file is provided with the toolbox and named as **pytorch_config.yaml**.
#
# Now it is the time to start training the network!

# %%
# There are many more functions you can set here, including which network to use!
# Check the docstring for `create_training_dataset` for all options you can use!

deeplabcut.create_training_dataset(
  path_config_file, net_type="resnet_50", engine=deeplabcut.Engine.PYTORCH
)
# Out:
# [(0.95,
#   3,
#   (array([26, 35, 59, 28, 11,  2, 34, 58, 40, 22,  4, 10, 30, 41, 33, 43, 49,
#            7, 14, 32, 50, 29, 42, 54, 18, 56, 27, 15,  5, 31, 16, 51, 20, 52,
#            8, 13, 25, 37, 17, 45, 48, 57, 38,  1, 12, 46, 24,  6, 23, 36, 21,
#           19,  9, 39, 55,  3,  0]),
#    array([53, 47, 44])))]

# %% [markdown]
# ## Start training:
# This function trains the network for a specific shuffle of the training dataset.

# %%
# Let's also change the display and save_epochs just in case Colab takes away
# the GPU... If that happens, you can reload from a saved point using the
# `snapshot_path` argument to `deeplabcut.train_network`:
#   deeplabcut.train_network(..., snapshot_path="/content/.../snapshot-050.pt")

# Typically, you want to train to ~200 epochs. We set the batch size to 8 to
# utilize the GPU's capabilities.

# More info and there are more things you can set:
#   https://deeplabcut.github.io/DeepLabCut/docs/standardDeepLabCut_UserGuide.html#g-train-the-network

deeplabcut.train_network(
    path_config_file,
    shuffle=1,
    displayiters=100,
    saveiters=1000,
    maxiters=10000,
    batch_size=1
)

# This will run until you stop it (CTRL+C), or hit "STOP" icon, or when it hits the end.
# Out:
# Training with configuration:
# data:
#   bbox_margin: 20
#   colormode: RGB
#   inference:
#     normalize_images: True
#   train:
#     affine:
#       p: 0.5
#       rotation: 30
#       scaling: [0.5, 1.25]
#       translation: 0
#     crop_sampling:
#       width: 448
#       height: 448
#       max_shift: 0.1
#       method: hybrid
#     gaussian_noise: 12.75
#     motion_blur: True
#     normalize_images: True
# device: auto
# inference:
#   multithreading:
#     enabled: True
#     queue_length: 4
#     timeout: 30.0
#   compile:
#     enabled: False
#     backend: inductor
#   autocast:
#     enabled: False
# metadata:
#   project_path: /content/drive/MyDrive/deeplabcut/30FPS-cavaloTeste1-2026-03-03
#   pose_config_path: /content/drive/MyDrive/deeplabcut/30FPS-cavaloTeste1-2026-03-03/dlc-models-pytorch/iteration-0/30FPSMar3-trainset95shuffle1/train/pytorch_config.yaml
#   bodyparts: ['Ext_Joelho', 'Ext_CanelaDianteira', 'Ext_CascoDianteiro', 'Ext_Perna', 'Ext_Jarrete', 'Ext_CanelaTraseira', 'Ext_CascoTraseiro', 'Int_Joelho', 'Int_CanelaDianteira', 'Int_CascoDianteiro', 'Int_Perna', 'Int_Jarrete', 'Int_CanelaTraseira', 'Int_CascoTraseiro']
#   unique_bodyparts: []
#   individuals: ['animal']
#   with_identity: None
# method: bu
# model:
#   backbone:
#     type: ResNet
#     model_name: resnet101
#     output_stride: 16
#     freeze_bn_stats: False
#     freeze_bn_weights: False
#   backbone_output_channels: 2048
#   heads:
#     bodypart:
#       type: HeatmapHead
#       weight_init: normal
#       predictor:
#         type: HeatmapPredictor
#         apply_sigmoid: False
#         clip_scores: True
#         location_refinement: True
#         locref_std: 7.2801
#       target_generator:
#         type: HeatmapGaussianGenerator
#         num_heatmaps: 14
#         pos_dist_thresh: 17
#         heatmap_mode: KEYPOINT
#         gradient_masking: False
#         generate_locref: True
#         locref_std: 7.2801
#       criterion:
#         heatmap:
#           type: WeightedMSECriterion
#           weight: 1.0
#         locref:
#           type: WeightedHuberCriterion
#           weight: 0.05
#       heatmap_config:
#         channels: [2048, 14]
#         kernel_size: [3]
#         strides: [2]
#       locref_config:
#         channels: [2048, 28]
#         kernel_size: [3]
#         strides: [2]
# net_type: resnet_101
# runner:
#   type: PoseTrainingRunner
#   gpus: None
#   key_metric: test.mAP
#   key_metric_asc: True
#   eval_interval: 10
#   optimizer:
#     type: AdamW
#     params:
#       lr: 0.0005
#   scheduler:
#     type: LRListScheduler
#     params:
#       lr_list: [[0.0001], [1e-05]]
#       milestones: [90, 120]
#   snapshots:
#     max_snapshots: 5
#     save_epochs: 25
#     save_optimizer_state: False
# train_settings:
#   batch_size: 1
#   dataloader_workers: 0
#   dataloader_pin_memory: False
#   display_iters: 100
#   epochs: 200
#   seed: 42
# Loading pretrained weights from Hugging Face hub (timm/resnet101.a1h_in1k)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# HTTP Request: HEAD https://huggingface.co/timm/resnet101.a1h_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# [timm/resnet101.a1h_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Data Transforms:
#   Training:   Compose([
#   Affine(always_apply=False, p=0.5, interpolation=1, mask_interpolation=0, cval=0, mode=0, scale={'x': (0.5, 1.25), 'y': (0.5, 1.25)}, translate_percent=None, translate_px={'x': (0, 0), 'y': (0, 0)}, rotate=(-30, 30), fit_output=False, shear={'x': (0.0, 0.0), 'y': (0.0, 0.0)}, cval_mask=0, keep_ratio=True, rotate_method='largest_box'),
#   PadIfNeeded(always_apply=True, p=1.0, min_height=448, min_width=448, pad_height_divisor=None, pad_width_divisor=None, position=PositionType.CENTER, border_mode=0, value=None, mask_value=None),
#   KeypointAwareCrop(always_apply=True, p=1.0, width=448, height=448, max_shift=0.1, crop_sampling='hybrid'),
#   MotionBlur(always_apply=False, p=0.5, blur_limit=(3, 7), allow_shifted=True),
#   GaussNoise(always_apply=False, p=0.5, var_limit=(0, 162.5625), per_channel=True, mean=0),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
# ], p=1.0, bbox_params={'format': 'coco', 'label_fields': ['bbox_labels'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True}, keypoint_params={'format': 'xy', 'label_fields': ['class_labels'], 'remove_invisible': False, 'angle_in_degrees': True, 'check_each_transform': True}, additional_targets={}, is_check_shapes=True)
#   Validation: Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
# ], p=1.0, bbox_params={'format': 'coco', 'label_fields': ['bbox_labels'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True}, keypoint_params={'format': 'xy', 'label_fields': ['class_labels'], 'remove_invisible': False, 'angle_in_degrees': True, 'check_each_transform': True}, additional_targets={}, is_check_shapes=True)
#
# Note: According to your model configuration, you're training with batch size 1 and/or ``freeze_bn_stats=false``. This is not an optimal setting if you have powerful GPUs.
# This is good for small batch sizes (e.g., when training on a CPU), where you should keep ``freeze_bn_stats=true``.
# If you're using a GPU to train, you can obtain faster performance by setting a larger batch size (the biggest power of 2 where you don't geta CUDA out-of-memory error, such as 8, 16, 32 or 64 depending on the model, size of your images, and GPU memory) and ``freeze_bn_stats=false`` for the backbone of your model.
# This also allows you to increase the learning rate (empirically you can scale the learning rate by sqrt(batch_size) times).
#
# Using 57 images and 3 for testing
#
# Starting pose model training...
# --------------------------------------------------
# Epoch 1/200 (lr=0.0005), train loss 0.01156, GPU: 1160.0/22563.1 MiB
# Epoch 2/200 (lr=0.0005), train loss 0.00839, GPU: 1160.0/22563.1 MiB
# Epoch 3/200 (lr=0.0005), train loss 0.00982, GPU: 1160.0/22563.1 MiB
# Epoch 4/200 (lr=0.0005), train loss 0.00951, GPU: 1160.0/22563.1 MiB
# Epoch 5/200 (lr=0.0005), train loss 0.01108, GPU: 1160.0/22563.1 MiB
# Epoch 6/200 (lr=0.0005), train loss 0.00705, GPU: 1160.0/22563.1 MiB
# Epoch 7/200 (lr=0.0005), train loss 0.00881, GPU: 1160.0/22563.1 MiB
# Epoch 8/200 (lr=0.0005), train loss 0.00802, GPU: 1160.0/22563.1 MiB
# Epoch 9/200 (lr=0.0005), train loss 0.00844, GPU: 1160.0/22563.1 MiB
# Training for epoch 10 done, starting evaluation
# Epoch 10/200 (lr=0.0005), train loss 0.00752, valid loss 0.01313, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         331.85
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:            1.12
#   metrics/test.mAR:            3.33
# Epoch 11/200 (lr=0.0005), train loss 0.00718, GPU: 1672.0/22563.1 MiB
# Epoch 12/200 (lr=0.0005), train loss 0.00773, GPU: 1672.0/22563.1 MiB
# Epoch 13/200 (lr=0.0005), train loss 0.00555, GPU: 1672.0/22563.1 MiB
# Epoch 14/200 (lr=0.0005), train loss 0.00498, GPU: 1672.0/22563.1 MiB
# Epoch 15/200 (lr=0.0005), train loss 0.00647, GPU: 1672.0/22563.1 MiB
# Epoch 16/200 (lr=0.0005), train loss 0.00588, GPU: 1672.0/22563.1 MiB
# Epoch 17/200 (lr=0.0005), train loss 0.00583, GPU: 1672.0/22563.1 MiB
# Epoch 18/200 (lr=0.0005), train loss 0.00512, GPU: 1672.0/22563.1 MiB
# Epoch 19/200 (lr=0.0005), train loss 0.00507, GPU: 1672.0/22563.1 MiB
# Training for epoch 20 done, starting evaluation
# Epoch 20/200 (lr=0.0005), train loss 0.00572, valid loss 0.01238, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         335.35
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           10.10
#   metrics/test.mAR:           10.00
# Epoch 21/200 (lr=0.0005), train loss 0.00565, GPU: 1672.0/22563.1 MiB
# Epoch 22/200 (lr=0.0005), train loss 0.00538, GPU: 1672.0/22563.1 MiB
# Epoch 23/200 (lr=0.0005), train loss 0.00519, GPU: 1672.0/22563.1 MiB
# Epoch 24/200 (lr=0.0005), train loss 0.00430, GPU: 1672.0/22563.1 MiB
# Epoch 25/200 (lr=0.0005), train loss 0.00437, GPU: 1672.0/22563.1 MiB
# Epoch 26/200 (lr=0.0005), train loss 0.00415, GPU: 1672.0/22563.1 MiB
# Epoch 27/200 (lr=0.0005), train loss 0.00416, GPU: 1672.0/22563.1 MiB
# Epoch 28/200 (lr=0.0005), train loss 0.00466, GPU: 1672.0/22563.1 MiB
# Epoch 29/200 (lr=0.0005), train loss 0.00393, GPU: 1672.0/22563.1 MiB
# Training for epoch 30 done, starting evaluation
# Epoch 30/200 (lr=0.0005), train loss 0.00421, valid loss 0.00931, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         146.53
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           28.91
#   metrics/test.mAR:           33.33
# Epoch 31/200 (lr=0.0005), train loss 0.00473, GPU: 1672.0/22563.1 MiB
# Epoch 32/200 (lr=0.0005), train loss 0.00402, GPU: 1672.0/22563.1 MiB
# Epoch 33/200 (lr=0.0005), train loss 0.00435, GPU: 1672.0/22563.1 MiB
# Epoch 34/200 (lr=0.0005), train loss 0.00422, GPU: 1672.0/22563.1 MiB
# Epoch 35/200 (lr=0.0005), train loss 0.00428, GPU: 1672.0/22563.1 MiB
# Epoch 36/200 (lr=0.0005), train loss 0.00406, GPU: 1672.0/22563.1 MiB
# Epoch 37/200 (lr=0.0005), train loss 0.00415, GPU: 1672.0/22563.1 MiB
# Epoch 38/200 (lr=0.0005), train loss 0.00446, GPU: 1672.0/22563.1 MiB
# Epoch 39/200 (lr=0.0005), train loss 0.00406, GPU: 1672.0/22563.1 MiB
# Training for epoch 40 done, starting evaluation
# Epoch 40/200 (lr=0.0005), train loss 0.00469, valid loss 0.00806, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         157.89
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           39.90
#   metrics/test.mAR:           46.67
# Epoch 41/200 (lr=0.0005), train loss 0.00377, GPU: 1672.0/22563.1 MiB
# Epoch 42/200 (lr=0.0005), train loss 0.00299, GPU: 1672.0/22563.1 MiB
# Epoch 43/200 (lr=0.0005), train loss 0.00417, GPU: 1672.0/22563.1 MiB
# Epoch 44/200 (lr=0.0005), train loss 0.00392, GPU: 1672.0/22563.1 MiB
# Epoch 45/200 (lr=0.0005), train loss 0.00418, GPU: 1672.0/22563.1 MiB
# Epoch 46/200 (lr=0.0005), train loss 0.00291, GPU: 1672.0/22563.1 MiB
# Epoch 47/200 (lr=0.0005), train loss 0.00378, GPU: 1672.0/22563.1 MiB
# Epoch 48/200 (lr=0.0005), train loss 0.00328, GPU: 1672.0/22563.1 MiB
# Epoch 49/200 (lr=0.0005), train loss 0.00282, GPU: 1672.0/22563.1 MiB
# Training for epoch 50 done, starting evaluation
# Epoch 50/200 (lr=0.0005), train loss 0.00347, valid loss 0.00707, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         179.92
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           30.00
#   metrics/test.mAR:           30.00
# Epoch 51/200 (lr=0.0005), train loss 0.00382, GPU: 1672.0/22563.1 MiB
# Epoch 52/200 (lr=0.0005), train loss 0.00328, GPU: 1672.0/22563.1 MiB
# Epoch 53/200 (lr=0.0005), train loss 0.00327, GPU: 1672.0/22563.1 MiB
# Epoch 54/200 (lr=0.0005), train loss 0.00349, GPU: 1672.0/22563.1 MiB
# Epoch 55/200 (lr=0.0005), train loss 0.00431, GPU: 1672.0/22563.1 MiB
# Epoch 56/200 (lr=0.0005), train loss 0.00311, GPU: 1672.0/22563.1 MiB
# Epoch 57/200 (lr=0.0005), train loss 0.00388, GPU: 1672.0/22563.1 MiB
# Epoch 58/200 (lr=0.0005), train loss 0.00386, GPU: 1672.0/22563.1 MiB
# Epoch 59/200 (lr=0.0005), train loss 0.00365, GPU: 1672.0/22563.1 MiB
# Training for epoch 60 done, starting evaluation
# Epoch 60/200 (lr=0.0005), train loss 0.00313, valid loss 0.00726, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         140.53
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           43.17
#   metrics/test.mAR:           43.33
# Epoch 61/200 (lr=0.0005), train loss 0.00333, GPU: 1672.0/22563.1 MiB
# Epoch 62/200 (lr=0.0005), train loss 0.00356, GPU: 1672.0/22563.1 MiB
# Epoch 63/200 (lr=0.0005), train loss 0.00270, GPU: 1672.0/22563.1 MiB
# Epoch 64/200 (lr=0.0005), train loss 0.00386, GPU: 1672.0/22563.1 MiB
# Epoch 65/200 (lr=0.0005), train loss 0.00346, GPU: 1672.0/22563.1 MiB
# Epoch 66/200 (lr=0.0005), train loss 0.00347, GPU: 1672.0/22563.1 MiB
# Epoch 67/200 (lr=0.0005), train loss 0.00253, GPU: 1672.0/22563.1 MiB
# Epoch 68/200 (lr=0.0005), train loss 0.00329, GPU: 1672.0/22563.1 MiB
# Epoch 69/200 (lr=0.0005), train loss 0.00271, GPU: 1672.0/22563.1 MiB
# Training for epoch 70 done, starting evaluation
# Epoch 70/200 (lr=0.0005), train loss 0.00336, valid loss 0.00657, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         178.47
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           16.63
#   metrics/test.mAR:           26.67
# Epoch 71/200 (lr=0.0005), train loss 0.00355, GPU: 1672.0/22563.1 MiB
# Epoch 72/200 (lr=0.0005), train loss 0.00336, GPU: 1672.0/22563.1 MiB
# Epoch 73/200 (lr=0.0005), train loss 0.00293, GPU: 1672.0/22563.1 MiB
# Epoch 74/200 (lr=0.0005), train loss 0.00301, GPU: 1672.0/22563.1 MiB
# Epoch 75/200 (lr=0.0005), train loss 0.00292, GPU: 1672.0/22563.1 MiB
# Epoch 76/200 (lr=0.0005), train loss 0.00335, GPU: 1672.0/22563.1 MiB
# Epoch 77/200 (lr=0.0005), train loss 0.00284, GPU: 1672.0/22563.1 MiB
# Epoch 78/200 (lr=0.0005), train loss 0.00316, GPU: 1672.0/22563.1 MiB
# Epoch 79/200 (lr=0.0005), train loss 0.00232, GPU: 1672.0/22563.1 MiB
# Training for epoch 80 done, starting evaluation
# Epoch 80/200 (lr=0.0005), train loss 0.00284, valid loss 0.00591, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         110.53
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           41.49
#   metrics/test.mAR:           43.33
# Epoch 81/200 (lr=0.0005), train loss 0.00266, GPU: 1672.0/22563.1 MiB
# Epoch 82/200 (lr=0.0005), train loss 0.00256, GPU: 1672.0/22563.1 MiB
# Epoch 83/200 (lr=0.0005), train loss 0.00326, GPU: 1672.0/22563.1 MiB
# Epoch 84/200 (lr=0.0005), train loss 0.00275, GPU: 1672.0/22563.1 MiB
# Epoch 85/200 (lr=0.0005), train loss 0.00256, GPU: 1672.0/22563.1 MiB
# Epoch 86/200 (lr=0.0005), train loss 0.00238, GPU: 1672.0/22563.1 MiB
# Epoch 87/200 (lr=0.0005), train loss 0.00258, GPU: 1672.0/22563.1 MiB
# Epoch 88/200 (lr=0.0005), train loss 0.00218, GPU: 1672.0/22563.1 MiB
# Epoch 89/200 (lr=0.0005), train loss 0.00263, GPU: 1672.0/22563.1 MiB
# Training for epoch 90 done, starting evaluation
# Epoch 90/200 (lr=0.0001), train loss 0.00261, valid loss 0.00659, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         441.26
#   metrics/test.rmse_pcutoff: 610.16
#   metrics/test.mAP:            0.00
#   metrics/test.mAR:            0.00
# Epoch 91/200 (lr=0.0001), train loss 0.00180, GPU: 1672.0/22563.1 MiB
# Epoch 92/200 (lr=0.0001), train loss 0.00219, GPU: 1672.0/22563.1 MiB
# Epoch 93/200 (lr=0.0001), train loss 0.00249, GPU: 1672.0/22563.1 MiB
# Epoch 94/200 (lr=0.0001), train loss 0.00238, GPU: 1672.0/22563.1 MiB
# Epoch 95/200 (lr=0.0001), train loss 0.00264, GPU: 1672.0/22563.1 MiB
# Epoch 96/200 (lr=0.0001), train loss 0.00233, GPU: 1672.0/22563.1 MiB
# Epoch 97/200 (lr=0.0001), train loss 0.00211, GPU: 1672.0/22563.1 MiB
# Epoch 98/200 (lr=0.0001), train loss 0.00204, GPU: 1672.0/22563.1 MiB
# Epoch 99/200 (lr=0.0001), train loss 0.00225, GPU: 1672.0/22563.1 MiB
# Training for epoch 100 done, starting evaluation
# Epoch 100/200 (lr=0.0001), train loss 0.00191, valid loss 0.00590, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         122.63
#   metrics/test.rmse_pcutoff:   7.89
#   metrics/test.mAP:           33.27
#   metrics/test.mAR:           40.00
# Epoch 101/200 (lr=0.0001), train loss 0.00170, GPU: 1672.0/22563.1 MiB
# Epoch 102/200 (lr=0.0001), train loss 0.00228, GPU: 1672.0/22563.1 MiB
# Epoch 103/200 (lr=0.0001), train loss 0.00200, GPU: 1672.0/22563.1 MiB
# Epoch 104/200 (lr=0.0001), train loss 0.00224, GPU: 1672.0/22563.1 MiB
# Epoch 105/200 (lr=0.0001), train loss 0.00164, GPU: 1672.0/22563.1 MiB
# Epoch 106/200 (lr=0.0001), train loss 0.00220, GPU: 1672.0/22563.1 MiB
# Epoch 107/200 (lr=0.0001), train loss 0.00187, GPU: 1672.0/22563.1 MiB
# Epoch 108/200 (lr=0.0001), train loss 0.00203, GPU: 1672.0/22563.1 MiB
# Epoch 109/200 (lr=0.0001), train loss 0.00176, GPU: 1672.0/22563.1 MiB
# Training for epoch 110 done, starting evaluation
# Epoch 110/200 (lr=0.0001), train loss 0.00292, valid loss 0.00671, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         322.13
#   metrics/test.rmse_pcutoff: 484.92
#   metrics/test.mAP:            7.85
#   metrics/test.mAR:           23.33
# Epoch 111/200 (lr=0.0001), train loss 0.00234, GPU: 1672.0/22563.1 MiB
# Epoch 112/200 (lr=0.0001), train loss 0.00198, GPU: 1672.0/22563.1 MiB
# Epoch 113/200 (lr=0.0001), train loss 0.00216, GPU: 1672.0/22563.1 MiB
# Epoch 114/200 (lr=0.0001), train loss 0.00210, GPU: 1672.0/22563.1 MiB
# Epoch 115/200 (lr=0.0001), train loss 0.00233, GPU: 1672.0/22563.1 MiB
# Epoch 116/200 (lr=0.0001), train loss 0.00191, GPU: 1672.0/22563.1 MiB
# Epoch 117/200 (lr=0.0001), train loss 0.00245, GPU: 1672.0/22563.1 MiB
# Epoch 118/200 (lr=0.0001), train loss 0.00230, GPU: 1672.0/22563.1 MiB
# Epoch 119/200 (lr=0.0001), train loss 0.00195, GPU: 1672.0/22563.1 MiB
# Training for epoch 120 done, starting evaluation
# Epoch 120/200 (lr=1e-05), train loss 0.00219, valid loss 0.00675, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         239.06
#   metrics/test.rmse_pcutoff: 354.47
#   metrics/test.mAP:            8.98
#   metrics/test.mAR:           26.67
# Epoch 121/200 (lr=1e-05), train loss 0.00192, GPU: 1672.0/22563.1 MiB
# Epoch 122/200 (lr=1e-05), train loss 0.00214, GPU: 1672.0/22563.1 MiB
# Epoch 123/200 (lr=1e-05), train loss 0.00166, GPU: 1672.0/22563.1 MiB
# Epoch 124/200 (lr=1e-05), train loss 0.00218, GPU: 1672.0/22563.1 MiB
# Epoch 125/200 (lr=1e-05), train loss 0.00239, GPU: 1672.0/22563.1 MiB
# Epoch 126/200 (lr=1e-05), train loss 0.00198, GPU: 1672.0/22563.1 MiB
# Epoch 127/200 (lr=1e-05), train loss 0.00235, GPU: 1672.0/22563.1 MiB
# Epoch 128/200 (lr=1e-05), train loss 0.00164, GPU: 1672.0/22563.1 MiB
# Epoch 129/200 (lr=1e-05), train loss 0.00194, GPU: 1672.0/22563.1 MiB
# Training for epoch 130 done, starting evaluation
# Epoch 130/200 (lr=1e-05), train loss 0.00190, valid loss 0.00623, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         277.17
#   metrics/test.rmse_pcutoff: 458.65
#   metrics/test.mAP:            8.98
#   metrics/test.mAR:           26.67
# Epoch 131/200 (lr=1e-05), train loss 0.00199, GPU: 1672.0/22563.1 MiB
# Epoch 132/200 (lr=1e-05), train loss 0.00219, GPU: 1672.0/22563.1 MiB
# Epoch 133/200 (lr=1e-05), train loss 0.00159, GPU: 1672.0/22563.1 MiB
# Epoch 134/200 (lr=1e-05), train loss 0.00171, GPU: 1672.0/22563.1 MiB
# Epoch 135/200 (lr=1e-05), train loss 0.00178, GPU: 1672.0/22563.1 MiB
# Epoch 136/200 (lr=1e-05), train loss 0.00223, GPU: 1672.0/22563.1 MiB
# Epoch 137/200 (lr=1e-05), train loss 0.00169, GPU: 1672.0/22563.1 MiB
# Epoch 138/200 (lr=1e-05), train loss 0.00171, GPU: 1672.0/22563.1 MiB
# Epoch 139/200 (lr=1e-05), train loss 0.00169, GPU: 1672.0/22563.1 MiB
# Training for epoch 140 done, starting evaluation
# Epoch 140/200 (lr=1e-05), train loss 0.00157, valid loss 0.00594, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         109.21
#   metrics/test.rmse_pcutoff: 115.74
#   metrics/test.mAP:           51.49
#   metrics/test.mAR:           56.67
# Epoch 141/200 (lr=1e-05), train loss 0.00166, GPU: 1672.0/22563.1 MiB
# Epoch 142/200 (lr=1e-05), train loss 0.00142, GPU: 1672.0/22563.1 MiB
# Epoch 143/200 (lr=1e-05), train loss 0.00169, GPU: 1672.0/22563.1 MiB
# Epoch 144/200 (lr=1e-05), train loss 0.00185, GPU: 1672.0/22563.1 MiB
# Epoch 145/200 (lr=1e-05), train loss 0.00138, GPU: 1672.0/22563.1 MiB
# Epoch 146/200 (lr=1e-05), train loss 0.00153, GPU: 1672.0/22563.1 MiB
# Epoch 147/200 (lr=1e-05), train loss 0.00167, GPU: 1672.0/22563.1 MiB
# Epoch 148/200 (lr=1e-05), train loss 0.00189, GPU: 1672.0/22563.1 MiB
# Epoch 149/200 (lr=1e-05), train loss 0.00184, GPU: 1672.0/22563.1 MiB
# Training for epoch 150 done, starting evaluation
# Epoch 150/200 (lr=1e-05), train loss 0.00145, valid loss 0.00660, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         113.04
#   metrics/test.rmse_pcutoff:   6.36
#   metrics/test.mAP:           43.17
#   metrics/test.mAR:           43.33
# Epoch 151/200 (lr=1e-05), train loss 0.00168, GPU: 1672.0/22563.1 MiB
# Epoch 152/200 (lr=1e-05), train loss 0.00172, GPU: 1672.0/22563.1 MiB
# Epoch 153/200 (lr=1e-05), train loss 0.00170, GPU: 1672.0/22563.1 MiB
# Epoch 154/200 (lr=1e-05), train loss 0.00172, GPU: 1672.0/22563.1 MiB
# Epoch 155/200 (lr=1e-05), train loss 0.00203, GPU: 1672.0/22563.1 MiB
# Epoch 156/200 (lr=1e-05), train loss 0.00186, GPU: 1672.0/22563.1 MiB
# Epoch 157/200 (lr=1e-05), train loss 0.00139, GPU: 1672.0/22563.1 MiB
# Epoch 158/200 (lr=1e-05), train loss 0.00153, GPU: 1672.0/22563.1 MiB
# Epoch 159/200 (lr=1e-05), train loss 0.00130, GPU: 1672.0/22563.1 MiB
# Training for epoch 160 done, starting evaluation
# Epoch 160/200 (lr=1e-05), train loss 0.00175, valid loss 0.00602, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         265.26
#   metrics/test.rmse_pcutoff: 299.14
#   metrics/test.mAP:           11.22
#   metrics/test.mAR:           33.33
# Epoch 161/200 (lr=1e-05), train loss 0.00139, GPU: 1672.0/22563.1 MiB
# Epoch 162/200 (lr=1e-05), train loss 0.00200, GPU: 1672.0/22563.1 MiB
# Epoch 163/200 (lr=1e-05), train loss 0.00176, GPU: 1672.0/22563.1 MiB
# Epoch 164/200 (lr=1e-05), train loss 0.00157, GPU: 1672.0/22563.1 MiB
# Epoch 165/200 (lr=1e-05), train loss 0.00153, GPU: 1672.0/22563.1 MiB
# Epoch 166/200 (lr=1e-05), train loss 0.00201, GPU: 1672.0/22563.1 MiB
# Epoch 167/200 (lr=1e-05), train loss 0.00165, GPU: 1672.0/22563.1 MiB
# Epoch 168/200 (lr=1e-05), train loss 0.00154, GPU: 1672.0/22563.1 MiB
# Epoch 169/200 (lr=1e-05), train loss 0.00177, GPU: 1672.0/22563.1 MiB
# Training for epoch 170 done, starting evaluation
# Epoch 170/200 (lr=1e-05), train loss 0.00210, valid loss 0.00616, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:          92.15
#   metrics/test.rmse_pcutoff:   6.45
#   metrics/test.mAP:           48.12
#   metrics/test.mAR:           50.00
# Epoch 171/200 (lr=1e-05), train loss 0.00154, GPU: 1672.0/22563.1 MiB
# Epoch 172/200 (lr=1e-05), train loss 0.00174, GPU: 1672.0/22563.1 MiB
# Epoch 173/200 (lr=1e-05), train loss 0.00170, GPU: 1672.0/22563.1 MiB
# Epoch 174/200 (lr=1e-05), train loss 0.00184, GPU: 1672.0/22563.1 MiB
# Epoch 175/200 (lr=1e-05), train loss 0.00174, GPU: 1672.0/22563.1 MiB
# Epoch 176/200 (lr=1e-05), train loss 0.00152, GPU: 1672.0/22563.1 MiB
# Epoch 177/200 (lr=1e-05), train loss 0.00192, GPU: 1672.0/22563.1 MiB
# Epoch 178/200 (lr=1e-05), train loss 0.00160, GPU: 1672.0/22563.1 MiB
# Epoch 179/200 (lr=1e-05), train loss 0.00173, GPU: 1672.0/22563.1 MiB
# Training for epoch 180 done, starting evaluation
# Epoch 180/200 (lr=1e-05), train loss 0.00207, valid loss 0.00720, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         128.68
#   metrics/test.rmse_pcutoff:   7.03
#   metrics/test.mAP:           43.17
#   metrics/test.mAR:           43.33
# Epoch 181/200 (lr=1e-05), train loss 0.00145, GPU: 1672.0/22563.1 MiB
# Epoch 182/200 (lr=1e-05), train loss 0.00189, GPU: 1672.0/22563.1 MiB
# Epoch 183/200 (lr=1e-05), train loss 0.00185, GPU: 1672.0/22563.1 MiB
# Epoch 184/200 (lr=1e-05), train loss 0.00196, GPU: 1672.0/22563.1 MiB
# Epoch 185/200 (lr=1e-05), train loss 0.00193, GPU: 1672.0/22563.1 MiB
# Epoch 186/200 (lr=1e-05), train loss 0.00202, GPU: 1672.0/22563.1 MiB
# Epoch 187/200 (lr=1e-05), train loss 0.00176, GPU: 1672.0/22563.1 MiB
# Epoch 188/200 (lr=1e-05), train loss 0.00147, GPU: 1672.0/22563.1 MiB
# Epoch 189/200 (lr=1e-05), train loss 0.00156, GPU: 1672.0/22563.1 MiB
# Training for epoch 190 done, starting evaluation
# Epoch 190/200 (lr=1e-05), train loss 0.00162, valid loss 0.00607, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:          69.73
#   metrics/test.rmse_pcutoff:   6.58
#   metrics/test.mAP:           43.17
#   metrics/test.mAR:           46.67
# Epoch 191/200 (lr=1e-05), train loss 0.00146, GPU: 1672.0/22563.1 MiB
# Epoch 192/200 (lr=1e-05), train loss 0.00160, GPU: 1672.0/22563.1 MiB
# Epoch 193/200 (lr=1e-05), train loss 0.00192, GPU: 1672.0/22563.1 MiB
# Epoch 194/200 (lr=1e-05), train loss 0.00159, GPU: 1672.0/22563.1 MiB
# Epoch 195/200 (lr=1e-05), train loss 0.00172, GPU: 1672.0/22563.1 MiB
# Epoch 196/200 (lr=1e-05), train loss 0.00161, GPU: 1672.0/22563.1 MiB
# Epoch 197/200 (lr=1e-05), train loss 0.00149, GPU: 1672.0/22563.1 MiB
# Epoch 198/200 (lr=1e-05), train loss 0.00198, GPU: 1672.0/22563.1 MiB
# Epoch 199/200 (lr=1e-05), train loss 0.00192, GPU: 1672.0/22563.1 MiB
# Training for epoch 200 done, starting evaluation
# Epoch 200/200 (lr=1e-05), train loss 0.00169, valid loss 0.00700, GPU: 1672.0/22563.1 MiB
# Model performance:
#   metrics/test.rmse:         327.54
#   metrics/test.rmse_pcutoff: 480.84
#   metrics/test.mAP:            8.98
#   metrics/test.mAR:           26.67

# %% [markdown]
# Note, that **when you hit "STOP" you will get a `KeyboardInterrupt` "error"! No worries! :)**

# %% [markdown]
# ## Start evaluating:
# This function evaluates a trained model for a specific shuffle/shuffles at a particular state or all the states on the data set (images)
# and stores the results as .csv file in a subdirectory under **evaluation-results-pytorch**

# %%
deeplabcut.evaluate_network(path_config_file, plotting=True)
# Here you want to see a low pixel error! Of course, it can only be as
# good as the labeler, so be sure your labels are good!
# Out:
# Evaluation scorer: DLC_Resnet101_30FPSMar3shuffle1_snapshot_best-140
# 100%|██████████| 57/57 [00:07<00:00,  7.37it/s]
# 100%|██████████| 3/3 [00:00<00:00,  8.28it/s]
# Evaluation results file: DLC_Resnet101_30FPSMar3shuffle1_snapshot_best-140-results.csv
# Evaluation results for DLC_Resnet101_30FPSMar3shuffle1_snapshot_best-140-results.csv (pcutoff: 0.1):
# train rmse             91.36
# train rmse_pcutoff     91.36
# train mAP              43.01
# train mAR              53.51
# test rmse             109.21
# test rmse_pcutoff     109.21
# test mAP               51.49
# test mAR               56.67
# Name: (0.95, 1, 140, -1, 0.1), dtype: float64

# %% [markdown]
# ## There is an optional refinement step you can do outside of Colab:
# - if your pixel errors are not low enough, please check out the protocol guide on how to refine your network!
# - You will need to adjust the labels **outside of Colab!** We recommend coming back to train and analyze videos...
# - Please see the repo and protocol instructions on how to refine your data!

# %% [markdown]
# ## Start Analyzing videos:
# This function analyzes the new video. The user can choose the best model from the evaluation results and specify the correct snapshot index for the variable **snapshotindex** in the **config.yaml** file. Otherwise, by default the most recent snapshot is used to analyse the video.
#
# The results are stored in hd5 file in the same directory where the video resides.

# %%
deeplabcut.analyze_videos(
    path_config_file,
    videofile_path,
    videotype=video_type,
    destfolder=destfolder,
)

# %% [markdown]
# ## Plot the trajectories of the analyzed videos:
# This function plots the trajectories of all the body parts across the entire video. Each body part is identified by a unique color.

# %%
deeplabcut.plot_trajectories(
    path_config_file,
    videofile_path,
    videotype=video_type,
    destfolder=destfolder,
)

# %% [markdown]
# Now you can look at the plot-poses file and check the "plot-likelihood.png" might want to change the "p-cutoff" in the config.yaml file so that you have only high confidnece points plotted in the video. i.e. ~0.8 or 0.9. The current default is 0.4.

# %% [markdown]
# ## Create labeled video:
# This function is for visualization purpose and can be used to create a video in .mp4 format with labels predicted by the network. This video is saved in the same directory where the original video resides.

# %%
deeplabcut.create_labeled_video(
    path_config_file,
    videofile_path,
    videotype=video_type,
    destfolder=destfolder,
)
